# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/web_tcp_ip.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      sender_ip destination_ip  protocol_ip  length  source_port  \
# 0           0  192.168.8.100  13.76.217.211            6      60        54180
# 1           1  192.168.8.100  13.76.217.211            6      52        54180
# 2           2  192.168.8.100  13.76.217.211            6     569        54180
# 3           3  13.76.217.211  192.168.8.100            6    1500          443
# 4           4  192.168.8.100  13.76.217.211            6      52        54180
#
#    destination_port  data_of_s         seq         ack flags  window  chksum  \
# 0               443         10   364700558           0     S   64240   41692
# 1               443          8   364700559  3869128378     A     502    9133
# 2               443          8   364700559  3869128378    PA     502   24744
# 3             54180          8  3869128378   364701076     A    1029   52073
# 4               443          8   364701076  3869129826     A     501    6847
#
#    urgptr  start_time    end_time
# ...
